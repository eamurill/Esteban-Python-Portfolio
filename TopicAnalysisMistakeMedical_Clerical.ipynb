# %%
# !pip install transformers datasets torch pandas scikit-learn openpyxl accelerate -U

import pandas as pd
import re
import numpy as np
from sklearn.model_selection import train_test_split
from datasets import Dataset, DatasetDict
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import torch

# Load the Excel file from the local directory
file_path = r"C:\Users\Michael\Downloads\BERTmodel\comments.xlsx"  # Update with your local path
data = pd.read_excel(file_path)

correct_comment_column = 'careprovidercomments'
medical_mistake_score_column = 'Medical_Mistakes'
clerical_mistake_score_column = 'Clerical_Mistakes'
bert_mistake_column = 'BERT_MistakeMedicalClerical'

# Work with the first 1000 rows
data = data.iloc[:1000]

# Drop rows with NaN values in the mistake score column(s)
data = data.dropna(subset=[medical_mistake_score_column, clerical_mistake_score_column])

data['temp_combined_mistake'] = np.where((data[medical_mistake_score_column] == 1) | (data[clerical_mistake_score_column] == 1), 1, 0)

mistake_score_column = 'temp_combined_mistake'

# Print unique values in the mistake score column after dropping NaNs
print("Unique values in the mistake score column after dropping NaNs:", data[mistake_score_column].unique())

# Function to clean punctuation
def clean_text(text):
    if isinstance(text, str):
        # Remove all punctuation except periods
        text = re.sub(r'[^\w\s.]', '', text)
    else:
        text = ''
    return text

# Clean the comments
data['cleaned_comment'] = data[correct_comment_column].apply(clean_text)

# Ensure mistake scores are 0 and 1
def ensure_mistake_scores(data, column):
    if not data[column].between(0, 1).all():
        raise ValueError("Mistake scores must be 0 or 1.")

ensure_mistake_scores(data, mistake_score_column)


# Split the data into training and testing sets (80/20 split)
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42,stratify = data[mistake_score_column])

# Print the sizes of the training and testing sets
print(f"Training set size: {len(train_data)} comments")
print(f"Test set size: {len(test_data)} comments")

# Free up memory by deleting the original dataframe
del data

# Convert the data to Hugging Face datasets
train_dataset = Dataset.from_pandas(train_data)
test_dataset = Dataset.from_pandas(test_data)
dataset_dict = DatasetDict({"train": train_dataset, "test": test_dataset})

# Free up memory by deleting the Pandas dataframes
del train_data, test_data

# Initialize tokenizer with smaller max_length
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

def tokenize_function(examples):
    return tokenizer(examples['cleaned_comment'], padding='max_length', truncation=True, max_length=256)

tokenized_datasets = dataset_dict.map(tokenize_function, batched=True)

def format_labels(examples):
    examples["labels"] = [int(label) for label in examples[mistake_score_column]]
    return examples

tokenized_datasets = tokenized_datasets.map(format_labels, batched=True)

# Free up memory by deleting the original datasets
del dataset_dict

# Print tokenized dataset sizes for debugging
print(f"Tokenized training set size: {len(tokenized_datasets['train'])} comments")
print(f"Tokenized test set size: {len(tokenized_datasets['test'])} comments")

# Load the model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

# Training arguments with reduced batch sizes
training_args = TrainingArguments(
    output_dir=r"C:\Users\Michael\Downloads\BERT_MODEL_TRAINING_RESULTS-20240701T162037Z-002",  # Update with your local path
    eval_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    num_train_epochs=3,
    weight_decay=0.01,
    fp16=True,
    logging_strategy="steps",
    logging_steps=50,
)

# Define evaluation metrics
def compute_metrics(p):
    preds = np.argmax(p.predictions, axis=1)
    precision, recall, f1, _ = precision_recall_fscore_support(p.label_ids, preds, average='macro')
    acc = accuracy_score(p.label_ids, preds)
    return {"accuracy": acc, "f1": f1, "precision": precision, "recall": recall}

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
    compute_metrics=compute_metrics,
)

# Print expected number of steps per epoch
expected_steps_per_epoch = len(tokenized_datasets['train']) // training_args.per_device_train_batch_size
print(f"Expected number of steps per epoch: {expected_steps_per_epoch}")

# Train the model
trainer.train()

# Unified predict function
def predict(texts, model, tokenizer, batch_size=4):
    model.eval()
    if not isinstance(texts, list):
        texts = texts.tolist()

    predictions = []
    probabilities = []

    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        encoded_inputs = tokenizer(batch_texts, padding=True, truncation=True, max_length=128, return_tensors='pt')

        with torch.no_grad():
            outputs = model(**encoded_inputs)

        logits = outputs.logits
        batch_probabilities = torch.nn.functional.softmax(logits, dim=-1)
        batch_predictions = torch.argmax(batch_probabilities, dim=-1)

        predictions.extend(batch_predictions.cpu().numpy())
        probabilities.extend(batch_probabilities.cpu().numpy())

    return np.array(predictions), np.array(probabilities)

def evaluate_model(test_dataset, model, tokenizer):
    texts = test_dataset['cleaned_comment']
    true_labels = test_dataset[mistake_score_column].tolist()

    predictions, probabilities = predict(texts, model, tokenizer)

    precision, recall, f1, _ = precision_recall_fscore_support(true_labels, predictions, average='macro')
    accuracy = accuracy_score(true_labels, predictions)

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

    return predictions, probabilities

# Convert the test dataset to a pandas DataFrame
test_data = tokenized_datasets['test'].to_pandas()

# Evaluate the model
predictions, probabilities = evaluate_model(test_data, model, tokenizer)

# Inspect the predictions and their probabilities

for i in range(len(test_data)):
    print(f"Text: {test_data['cleaned_comment'].iloc[i]}")
    print(f"True Label: {test_data[mistake_score_column].iloc[i]}")
    print(f"Predicted Label: {predictions[i]}")
    print(f"Probabilities: {probabilities[i]}")
    print()

# Re-load the full dataset including comments without mistake scores
full_data = pd.read_excel(file_path)

# Clean the comments
full_data['cleaned_comment'] = full_data[correct_comment_column].apply(clean_text)

# Get predictions
comments_to_predict = full_data['cleaned_comment'].tolist()
predicted_labels, predicted_probabilities = predict(comments_to_predict, model, tokenizer)

# Add predicted labels to the data in the BERT_Mistake column
full_data[bert_mistake_column] = predicted_labels

# List of columns to keep
columns_to_keep =['ID', 'unidentifiableid', 'Combined_Sentiment', 'Combined_Wait',
       'Updated_Wait', 'BERT_Sentiment5',
       'BERT_Sentiment', 'BERT_Wait', 'BERT_MistakeMedical',
       'BERT_MistakeClerical', 'BERT_MistakeMedicalClerical',
       'BERT_MistakeCommunication', 'BERT_MistakeAll', 'careprovidercomments',
       'Medical_Mistakes', 'Clerical_Mistakes', 'Communication_Mistakes']
# Drop columns not in the list
full_data = full_data[columns_to_keep]

# Save the full data with predictions back to the original Excel file
full_data.to_excel(file_path, index=False)  # Overwrite the original file
# Out:
# Requirement already satisfied: transformers in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (4.44.2)
# Requirement already satisfied: datasets in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (2.21.0)
# Requirement already satisfied: torch in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (2.4.0)
# Requirement already satisfied: pandas in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (1.5.1)
# Requirement already satisfied: openpyxl in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: accelerate in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (0.33.0)
# Requirement already satisfied: filelock in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.5.0)
# Requirement already satisfied: aiohttp in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.9.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: et-xmlfile in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: psutil in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: six>=1.5 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch) (1.3.0)
# Unique values in the mistake score column after dropping NaNs: [1 0]
# Training set size: 800 comments
# Test set size: 200 comments
# C:\Users\Michael\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Tokenized training set size: 800 comments
# Tokenized test set size: 200 comments
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Expected number of steps per epoch: 400
#     <div>
#
#       <progress value='1200' max='1200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1200/1200 30:11, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.109900</td>
#       <td>0.110769</td>
#       <td>0.980000</td>
#       <td>0.970101</td>
#       <td>0.960400</td>
#       <td>0.980000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.232200</td>
#       <td>0.065361</td>
#       <td>0.980000</td>
#       <td>0.981949</td>
#       <td>0.984948</td>
#       <td>0.980000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000200</td>
#       <td>0.150071</td>
#       <td>0.975000</td>
#       <td>0.967595</td>
#       <td>0.960302</td>
#       <td>0.975000</td>
#     </tr>
#   </tbody>
# </table><p>
# C:\Users\Michael\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Michael\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9800
# Precision: 0.9604
# Recall: 0.9800
# F1 Score: 0.9701
# Text: in all fairness to him i have hearing loss and havent been able to get aids.  i know communicating with me can be irritating.  i felt the dr was irritated if i asked him to repeat something i didnt catch the first time.  the subject of pain was so absorbing the whole appt. that i didnt have a chance to discuss other problems i am having.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9982762e-01 1.7229204e-04]
#
# Text: Dr. Cooper has always been responsive courteous personable.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999188e-01 8.116685e-05]
#
# Text: Very courteous and helpful
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999192e-01 8.085923e-05]
#
# Text: I have really grown to like and respect Bonnie Stephens.  I only hope to be able to continue to see her in the future.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9989784e-01 1.0219914e-04]
#
# Text: excellent experience
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992216e-01 7.7856334e-05]
#
# Text: Nancy Veit was the nurse practitioner and she was superb  thorough detailed interested and explained everything very well. She also has been great at my follow up questions and returning calls as soon as possible.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992073e-01 7.9260615e-05]
#
# Text: I always enjoy coming to visit Dr. Zinkaham. He is kind and caring He listens well to my concerns. He is an amazing caring Dr.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992025e-01 7.9738376e-05]
#
# Text: The follow up care instructions were given a little quickly and I had to ask for them to be repeated so Id remember them.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9986887e-01 1.3110653e-04]
#
# Text: Wendy is very kind caring and sweet.  You can tell she genuinely cares about you and she takes the time to address your questions and explain your medicalhealth issues.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999223e-01 7.777760e-05]
#
# Text: Dr Stoneburner was extremely interested in my problems and he has become my primary care physician
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992204e-01 7.7906378e-05]
#
# Text: My urologist is the best.  Cant praise him enough.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992192e-01 7.8055484e-05]
#
# Text: I thought Hugh Davis was great.  I understand that he is not a doctor but he seemed competent and efficient.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991417e-01 8.5879285e-05]
#
# Text: Great exprience. Even though my problem is minor compared to other patients I always felt like the most important person there. Dr. Soission is wonderful and he makes a scary experience more comfortable.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992156e-01 7.8459881e-05]
#
# Text:
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9981755e-01 1.8248090e-04]
#
# Text: Dr. Berks is the best.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999168e-01 8.318689e-05]
#
# Text: Excellent
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992514e-01 7.4820673e-05]
#
# Text: Dr Nelson is very good at explaining things in lay mans terms as well as giving analogies that make things easier to understand
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999218e-01 7.817467e-05]
#
# Text: The information that I attain each time I go is very good. Both my husband and I are very pleased with this facility and have had the opportunity toexperience other topo grande institutions which cannot hold a candle to you.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999051e-01 9.482596e-05]
#
# Text: I consider Dr. Bowen to be the very best.  It isnt necessary to my satisfection but I like him very much too.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999082e-01 9.180609e-05]
#
# Text: Intelligent efficient without hurry useful discussion and information sense of humor
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9988317e-01 1.1685181e-04]
#
# Text: perhaps the best service I can recall ever receiving
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999137e-01 8.632718e-05]
#
# Text: All very good but Press  Ganey is an expensive waste of time and money
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999193e-01 8.066446e-05]
#
# Text: I like and prefer them.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.99897242e-01 1.02698534e-04]
#
# Text: I do not plan to go back.  Ive decided to go to another Dr. Next week at my own expence if necessary.  I have Retinites Pigmentosis and need a doctor I feel confident in.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9984837e-01 1.5165168e-04]
#
# Text: Highly professional and friendly
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999211e-01 7.893365e-05]
#
# Text: Doctor Myers was able to help us with a medication problem that will increase my ability to be at home safely.  It is greatly appreciated.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9990785e-01 9.2194030e-05]
#
# Text: Staff reported they were running late but were not aware of any problem
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9987280e-01 1.2721651e-04]
#
# Text: problems with survey does not allow completion.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.997979e-01 2.020882e-04]
#
# Text: Dr. Backmann is a great physician. He took great care of me. He also replied to my MyChart message promptly.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999238e-01 7.621083e-05]
#
# Text: Dr. Bezzant was professinal in every way.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9988127e-01 1.1868901e-04]
#
# Text: Once I was in the room with the doctor she made me feel like I was her only patient.  She was not rushed and made me feel like all of my concerns were valid.  She took the time to help e come up with a plan and ease my fears associated with my visit reason.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9987888e-01 1.2107548e-04]
#
# Text: Excellent attention from Fellow and Dr Kunkel
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992335e-01 7.6624092e-05]
#
# Text: I have been VERY impressed with Brett. My wife and mother now see him for all their care.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991190e-01 8.8103996e-05]
#
# Text: we saw a pediatric fellow who did our echo he was great. we then saw the doctor who only spent about 2 minutes with us. he was very brief and although the information he provided was sufficient it would have been nice had he spent at least a few minutes with us rather than the rushed feeling that because we didnt have any issues we werent worth his time.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991167e-01 8.8297442e-05]
#
# Text: Dr. Young is always so kind and compassionate towards us and Tala.  She always takes our feedback into consideration and we can tell she really wants to help Tala see and function as well as she possibly can.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999174e-01 8.265433e-05]
#
# Text: good
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999268e-01 7.315166e-05]
#
# Text: Tyler is great with kids. Its always good when your child wants to go back to the doctors.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9990416e-01 9.5891330e-05]
#
# Text: Dr. Douglas Powell is an absolutely wonderful physician
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992371e-01 7.6329394e-05]
#
# Text: Dr. Lawrence was as good as anyone could have asked
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9989736e-01 1.0258940e-04]
#
# Text: Good
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999268e-01 7.315166e-05]
#
# Text: Dr. Thulin was very helpful in addressiing the problem of delusions.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9989522e-01 1.0476392e-04]
#
# Text: The PAs and NPs are great and spend the time it takes to give great care. I have confidence in the Doctors abilities but he is always late and in a hurry to get in and out.    it
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999101e-01 8.991130e-05]
#
# Text: Love love love Dr. M and his staff.  Only area for improvement is in coordinating scheduling of echo MRI and next Dr. M visit  needs nudging on my part to get that all done.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9987221e-01 1.2773054e-04]
#
# Text: Your survey needs to have either a NA box or instructions to indicate not to check any box if a question is nonapplicable.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9989319e-01 1.0681909e-04]
#
# Text: He spend more time than he probably had.  Hopefully he didnt miss an appointment that was elsewhere on campus.  It was just so good to finally talk to a professional about Parkinsons.  I have to say Im still afraid of the damaging effects of the disease when taking medicines.  Certainly had a hope for awhile that exercise and will power could keep the symptoms at bay. Everything has moved quickly in last 6 months.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.998406e-01 1.593173e-04]
#
# Text: Johanna Greenberg is an outstanding PA.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991894e-01 8.1106657e-05]
#
# Text: all good
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992216e-01 7.7815952e-05]
#
# Text: Dr Farrukh even gave me a hug ... she is wonderful  Best Dr ever
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992490e-01 7.5151904e-05]
#
# Text: We feel very confidante with Dr Colman
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999192e-01 8.081259e-05]
#
# Text: Dr. Wilson has an excellent bedside manner.  I feel very comfortable with him and he makes me feel like he is giving me his complete attention.  Although I know hes very busy he never seems rushed.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992204e-01 7.7942059e-05]
#
# Text: great experience every time.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9990344e-01 9.6599018e-05]
#
# Text: love dr Jackson.  always concerned about the way Im feeling and wants to help with getting and feeling without pain
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999232e-01 7.674496e-05]
#
# Text: Again my experience at the clinic has always been very good.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9988043e-01 1.1954316e-04]
#
# Text: Dr. Villalobos is AMAZING  Very down to earth and easy to talk to.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991751e-01 8.2539336e-05]
#
# Text: i was the last appointment of the day so felt rushed during appointment and some of the issues i went in for were not addressed. waist of anappointment and copay.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999076e-01 9.240298e-05]
#
# Text: I still dont really understand what is causing my issue. When I asked about pain medication I was told that its just a pain that I would have to deal with and he prescribed me some medication for arthritis or something that I dont even suffer from so I dont understand why the medication would be helpful. He suggested physical therapy for a long period of time even though it would be painful. He seemed rushed and I did not get to see all the photos from my MRI. Also the results of the MRI have not been posted to My Chart so I dont know what the radiologist that was going to read the images said.
# True Label: 1
# Predicted Label: 0
# Probabilities: [9.9957663e-01 4.2333876e-04]
#
# Text: I recommend Dr C. Miller to any of my friends or loved ones that need attention for my same condition.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9982774e-01 1.7220729e-04]
#
# Text: Although I have never heard from the physician about my lab results.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9986398e-01 1.3599743e-04]
#
# Text: Dr. Abraham is very personable and made certain all of our questions and concerns were addressed.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992514e-01 7.4814110e-05]
#
# Text: Everyone was very helpful.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991953e-01 8.0458187e-05]
#
# Text: I have had very good service throughout my Moran experiences.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999192e-01 8.080627e-05]
#
# Text: Dr Norton was wonderful and very thorough. She further explained the time delay and was very apologetic. I was not in a rush so it was totally fine.  She was wonderful
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991405e-01 8.5917287e-05]
#
# Text: he is the BEST
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992156e-01 7.8405734e-05]
#
# Text: good
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999268e-01 7.315166e-05]
#
# Text: Laura is the best  bar none
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999105e-01 8.948295e-05]
#
# Text: Dr. Junkins has excellent communication skills and is an outstanding physician.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999201e-01 7.985129e-05]
#
# Text: Dr Pham is the most caring Primary Care Doctor I have ever had.  I would and have recommended her to everyone.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992394e-01 7.6035525e-05]
#
# Text: dr. summers is the best doctor at helping me keep my illness under control. he is very knowledgable.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992347e-01 7.6571720e-05]
#
# Text: Dr Bull was very patient he took the time to answer all my questions.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999137e-01 8.630388e-05]
#
# Text: Doctor Day spent an enormous amount of focus figuring out what was causing my problem. The result of her evaluation was that I was sent to the hospital for potential Pulmonary Embolisms in the lung. Dr. Day was spot on and saved my life. There was an excellent chance I would not have made it. DR. DAY IS THE BEST AND I OWE HER MY LIFE. WHAT A KNOWLEDGEABLE AND PERCEPTIVE AND TAKE CHARGE PERSON
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9988914e-01 1.1079305e-04]
#
# Text: Everything about my visits and surgery has been great other than the fact that one week after surgery I called to refill my pain medicine and it was not done until I physically went to the clinic one week later.  When I called I felt like I was treated like I was being a pest.  Well one week after surgery there is a lot of pain.
# True Label: 1
# Predicted Label: 0
# Probabilities: [9.9983668e-01 1.6331607e-04]
#
# Text: I did have questions after the exam that I will need to call in to get answered that I wished had been written down for example Do I have to wear a mask during my whole chemo therapy visit.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9984324e-01 1.5675306e-04]
#
# Text: I have recommended Dr. Jones to other people I know because he listens makes you feel important pays attention to you and knows his stuff.  Makes you feel happy when you leave.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999045e-01 9.544822e-05]
#
# Text: Dr. Muntz is an amazing doctor and in the four years that he has been our daughters doctor we have never felt like she was getting anything but the very best care.  Dr. Muntz is absolutely an amazing doctor and there are not enough words to express our deep appreciation for what he has done for Abbie.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999211e-01 7.892077e-05]
#
# Text: Utah is so fortunate to have a facility staffed with such wonderful caring professionals.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999026e-01 9.739957e-05]
#
# Text: Steve Wolf is an excellent practitioner who understands the unique disease that I have and is genuinely trying to solve the problem. His analysis was very helpful and I hope it reduces the inflammation and other connected issues.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991107e-01 8.8917724e-05]
#
# Text: great
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991834e-01 8.1625738e-05]
#
# Text: The dr spoke to me for less than 2 minutes and said only that she could not help mejust suggested that I check with my primary care physician about obtaining a pain management specialist. VERY disappointing since I had expected a physical exam to establish where I still have pain since my May 9 surgical procedure cervical nerve block injection did not seem to help and possibly other testing recommendations which the male nurse even brought up with me before the dr came in. Although it may be true that I do not need the drs services in the future cervical disc fusion I was hoping for some caring discussion about my continuing problem which generates from my cervical spine I left this very brief moment wont even call it an appointment with no help and no answers whatsoever as if my case is being dismissed from the neurosurgery category
# True Label: 0
# Predicted Label: 0
# Probabilities: [0.9875666  0.01243345]
#
# Text: My son had a good experience with Bryan Franco. He showed he could relate with my son at many levels showed he cared for his interests asked questions about his school sports friends. Took his time to answer any questions or concerns we both had. This has been our first appointment with Bryan and I and my son were satisfied with the way we were treated. I would definitely recommend Bryan with friends and family.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.99895930e-01 1.04071216e-04]
#
# Text: Hutch is awesome
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992526e-01 7.4770040e-05]
#
# Text: Dr. Tristani is wonderful
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999275e-01 7.250510e-05]
#
# Text: I have never had a doctor be more concerned. I was in her care for 2 hours with her checking out problem the entire time.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.99889731e-01 1.10229375e-04]
#
# Text: all around excellent staff and service of care.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999175e-01 8.245484e-05]
#
# Text: The dr was wonderful I am glad that I chose to go to her because she took her time
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992430e-01 7.5676304e-05]
#
# Text: I have complete confidence in all of the Doctors who have and are treating me at the Medical Center.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.99889374e-01 1.10619614e-04]
#
# Text: My care provider is very thorough and knowledgeable.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991906e-01 8.0933365e-05]
#
# Text: I felt a little cheated on the time I was given with the care giverespecially since we had driven 477 miles one way for this checkup visit.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.99897599e-01 1.02428705e-04]
#
# Text: I am so happy with my providers as well as the U of U
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991989e-01 8.0061574e-05]
#
# Text: Great doctor.  She answers any questions that I have.  She always shows concern over my medical issues.  She has a very caring demeanor about her.  She makes me feel like I am her only pt. I would recommend her to anyone.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992025e-01 7.9758756e-05]
#
# Text: Dr. Bowen is a wonderful physicianhuman through caring competent...and he loves his work
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992824e-01 7.1752074e-05]
#
# Text: Again everything was done in a manner that gave us the feeling that everyone genuinely cared.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9986625e-01 1.3378309e-04]
#
# Text: We have had 2 appts. with Dr. Young and she has spent more time with us than any other doctor ever has including our primary care pediatrician whom we really like.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.998958e-01 1.042178e-04]
#
# Text: Followup care given via phone by nurse to my husband very confusing.  Not clear what the doctor wanted my husband to do.  Nurse gave conflicting information.  When calling on the phone to patients the message should be short precise and clear.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9986303e-01 1.3694582e-04]
#
# Text: Dr. Doane is a very good listener.  He thinks through issues well.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999174e-01 8.264922e-05]
#
# Text: Dr. Tricot is absolutely the most caring physician that I have ever known. The genuine love of his profession of healing is very evident by his hard work and many years of education with his focus on multiple myeloma. Every patient knows he is the most important person at the time of his visit and that he has the full attention of the Doctor. Yet Dr. Tricot never fails to inquire about the patients family which brings the element of real concern for the whole wellbeing of those for which he is attending.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9990594e-01 9.3998417e-05]
#
# Text: All medical personnel were very professional on time and helpful
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992847e-01 7.1467104e-05]
#
# Text: I liked Dr Parker the first time we met.  He was kind and I felt as though I was in good hands with him.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999076e-01 9.235611e-05]
#
# Text: My daughter was recommended to have an eye procedure done. My in surname was to expire at the end of the month. Dr. Marielle Young fit her into the schedule to help us afford the surgery.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9983144e-01 1.6851177e-04]
#
# Text: there is no one better than Dr. Legant Ive been away from Utah and my experiences with other doctors just reinforced that opinion
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9988878e-01 1.1125964e-04]
#
# Text: My health care provider is EXCELLENT
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999231e-01 7.686450e-05]
#
# Text: Only the best Michelle you could open up your own clinic and you would be very successful.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.99888897e-01 1.11035246e-04]
#
# Text: Dr. Shakeri has always shown great respect and care for me as one of her patients.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999211e-01 7.892258e-05]
#
# Text: Dr. Kolb was just terrific relaxed attentive caring thorough in history and physical extremely good at eliciting concerns and answering questions involved the patient and family in decision making about further evaluation and management. Its hard to imagine how his care could have been any better
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992490e-01 7.5038246e-05]
#
# Text: I was treated like. person. with concern and care. I am asked if I understand my condition and explained what I dont. I am explained what is happening to me. I am reassured that I am in good hands. and I feel at ease because I am being talked to and looked at.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9988878e-01 1.1124669e-04]
#
# Text: I have not had better care anywhere.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9987900e-01 1.2094958e-04]
#
# Text: i was very impressed by Dr. Thulins thoroughness.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9990463e-01 9.5367614e-05]
#
# Text: Ally was amazing She genuinely cared about my problem and acted like a friend as well as a doctor. Best experience I have ever had at this clinic.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999192e-01 8.087528e-05]
#
# Text: none since it was only a walk in for flue shot
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9988365e-01 1.1631729e-04]
#
# Text: Took the time to answer any questions that I had.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9976403e-01 2.3598704e-04]
#
# Text: Dr. Backman is the best.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991465e-01 8.5357329e-05]
#
# Text: Follow care was not discussed so I was not pleased with that.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999074e-01 9.260568e-05]
#
# Text: Dr. Powell is very concerned about my condition.  he answers all my questions extensively and in language I understand. Hes always chivalrous and kind
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992669e-01 7.3365234e-05]
#
# Text: This was a oneyear postsurgical followup visit. There was no discussion of medications.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9975580e-01 2.4414572e-04]
#
# Text: VERY pleased with the visit esp. the time Dr. Hood took to educate me about my condition generally and about options specifically
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9990094e-01 9.9050761e-05]
#
# Text: I am impressed with Dr. Tward and his team.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.99879837e-01 1.20157325e-04]
#
# Text: Teast conducted and medical plan provided changed my life.  I have been suffering for 30 years but no more
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9989128e-01 1.0873898e-04]
#
# Text: I think it would be nice to see the actual doctor more often rather than the pa.  I usually feel a bit rushed when I meet with a pa.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.998211e-01 1.788558e-04]
#
# Text: actually most of this fals in the NA category again  you need this choice since I was only there for a bone density scan
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.998586e-01 1.413848e-04]
#
# Text: The primary care physician is excellent however the experience I had with the neurosurgeon was very poor. He overlooked a specific condition that I had and perscribed a medicine that was contradictory to my condition. I had a severe reaction which resulted in a life threatening condition that I will now for the rest of my life have to take a preventive medicine for so the condition will not reoccur. I have also sustained kidney damage from the drug reaction so I have recurring doctor visits and bills.
# True Label: 1
# Predicted Label: 0
# Probabilities: [9.9968493e-01 3.1510420e-04]
#
# Text: Excellent quality of care.  I really appreciated receiving a print out of my note at the end of my visit.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991584e-01 8.4167463e-05]
#
# Text: Dr. Grossman and the clinic staff are highly professional helpful friendly and thorough.  I am always pleased with the services I receive at Huntsman and from Dr. Grossman.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991608e-01 8.3970896e-05]
#
# Text: Love Julia...very informative and made me feel that she cared.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999144e-01 8.557060e-05]
#
# Text: I am always impressed with the degree at which Dr. Digre shows compassion and concern. She also shows a positive impression for a good outlook and confidence.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991822e-01 8.1824386e-05]
#
# Text: Dr. Wilson seems genuinely concerned about my heart health.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991095e-01 8.9083478e-05]
#
# Text: Dr Henrie was efficient and pleasant to deal with and put us at ease.  He was also forthcoming about his training and education to deal with an additional problem that I brought up and handled it with expertise.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999155e-01 8.450217e-05]
#
# Text: Excellent
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992514e-01 7.4820673e-05]
#
# Text: Couldnt have been better. Thank you
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9990654e-01 9.3489238e-05]
#
# Text: I have been seeing Melissa for about 15 years and have never had a problem.  When see moved from SLC to park city I how drive to park city even know it is 20 miles away form her SLC office.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9985826e-01 1.4166250e-04]
#
# Text: I LOVE Dr. Kokeny MD she is a WONDERFUL CARING person. She has and is my favorite Dr. she listens and has such great kindness THANK YOU
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999230e-01 7.701755e-05]
#
# Text: I have recommended Dr. Sawitzke to others.  I have 100 confidence in his care and judgement.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999136e-01 8.642676e-05]
#
# Text: I absolutely love my OB she is amazing she shows sincere concern for me. She is very friendly and professional at the same time. I tell everyone I know to go to her. She is amazing I trust her answers and know she has my best interest in mind.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9990857e-01 9.1438087e-05]
#
# Text: very good
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999238e-01 7.621112e-05]
#
# Text: new doctor for meliked her very much.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999136e-01 8.647169e-05]
#
# Text: I dont like being asked to feel out a survey each time I come in.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9985182e-01 1.4820842e-04]
#
# Text: doesnt listen at all walks in room for 30 seconds then leaves
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9985623e-01 1.4379265e-04]
#
# Text: Too long to wait between visits.  Ive done what I was told and would like to see the provider for a follow up.  Next available is OCTOBER and it is July now.  I need the help NOW so waiting that long is not good.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9985909e-01 1.4084789e-04]
#
# Text: When I was treated for prostrate cancer all the care was excellent and I couldnt have asked for better help and information with all my doctors from surgen through radiation. When I went for foot care and knee care I felt very dissatisfied the service.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9987757e-01 1.2239229e-04]
#
# Text: He is good..
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9988401e-01 1.1596157e-04]
#
# Text: I am not seen by a doctor or midlevel provider when I have my infusions
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.998529e-01 1.470451e-04]
#
# Text: Dr. Buckman was excellent  impressed with his explanations.  I am sure it is not easy explaining this to a nonmedical person.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999002e-01 9.977492e-05]
#
# Text: the aide forgot to send my prescription to the pharmacy so I had to wait an extra day to get it. there were also no notes in my chart to indicate what the medication was supposed to be.
# True Label: 1
# Predicted Label: 0
# Probabilities: [0.9751335  0.02486658]
#
# Text: We always have a positive experience with doctor Kennedy. We feel that he truly cares about us were not just a chart to him. He always takes the time to listen to what we have to say and doesnt belittle our opinions or concerns.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9990034e-01 9.9657111e-05]
#
# Text: Dr. Moshifar is a highly skilled professional  He does a great job.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999199e-01 8.014454e-05]
#
# Text: I have always had a very good service at the Redwood Clinic The testing was done very well I have no complaints.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991584e-01 8.4098137e-05]
#
# Text: I trust Dr Keri Gibson with my life. I was going through a miscarraige. She called me over the weekend  kept checking on me. when I ended up in the ER she was up at the hospital doing surgeries  came down several times during her busy day to check on me. Even though a D  C was the last option Dr Gibson  myself wanted to do I ended up needing a D  C and she made time to do that for me. She is always so caring and personable. She makes you feel as though you are her most important patient. I recommend her to everyone I love Dr Gibson
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9974161e-01 2.5834117e-04]
#
# Text: Bettykathyjodie great
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999018e-01 9.823702e-05]
#
# Text: Dr. Hoffman is wonderful. I was amazed at his memory when it came to Maddie. It really put us at ease when he knew exactly what was going on with her and could see her improvement even though he had not seen her in months.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991763e-01 8.2389844e-05]
#
# Text: I appreciated Dr. Tysers explanation and treatment. I didnt expect to have everything completed in one visit.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.998765e-01 1.235441e-04]
#
# Text: Dr. Shprecher was very patient thorough and listened intently to anything I asked or expressed.  Very impressive
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999262e-01 7.381843e-05]
#
# Text: I feel like Dr. Glasgow likes me as a person and considers me a friend. I trust him.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999069e-01 9.315055e-05]
#
# Text: Dr. Owan was excellent.  He took plenty of time explaining potential problems and treatmentsremedies.  He was very thorough and detailed.  And he took TIME so few doctors still do this.  He was a breath of fresh air.  Thank you
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999182e-01 8.180247e-05]
#
# Text: Time enough to do the required tasks.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9978679e-01 2.1326056e-04]
#
# Text: Dont have enough information to give a good or bad care provider a recommendation at this time.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9983585e-01 1.6408920e-04]
#
# Text: Dr. Zorn listened carefully to some concerns I have about PD and meds.  She also carefully noted my condition and how I was doing.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.99879718e-01 1.20309356e-04]
#
# Text: The dr. under fellowship was great also and listened to what I said and then acted upon it.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992120e-01 7.8833524e-05]
#
# Text: My dad saw Amy before he had his Left TKA to manage pain with injections.  His right knee is bad and should be replaced but he will most likely see Amy before proceding that route  shes great.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.997415e-01 2.584870e-04]
#
# Text: I am fortunate to have such caring medical professionals.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999002e-01 9.974695e-05]
#
# Text: Dr. Sharp is very congenial and professional
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992764e-01 7.2410781e-05]
#
# Text: Dr. Craig is a wonderful doctor.   He has helped me so much with my health issues.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999244e-01 7.561888e-05]
#
# Text: Dr. Mirci was great.  He put me at ease and was very pleasant.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992263e-01 7.7302961e-05]
#
# Text: Dr. Agerwal is the best We love him
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992585e-01 7.4126627e-05]
#
# Text: Highly recommended diagnosis was quick and easily treatable.  Cant ask for much more. Super friendly.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999211e-01 7.885277e-05]
#
# Text: doctor very good  would recommend
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991596e-01 8.4072250e-05]
#
# Text: Dr Junkins and Dr Winter are both some of my very favorite doctors.  I have many doctors in my life.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9990547e-01 9.4573843e-05]
#
# Text: Excellent Dr.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9988532e-01 1.1462756e-04]
#
# Text: We were so fortunate to have Dr. Hung Khong and would recommend him to anyone in his specialty.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9986863e-01 1.3140593e-04]
#
# Text: The nurse was professional friendly and easy to understand.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999095e-01 9.049700e-05]
#
# Text: My care providers are the best that i have ever had. Would never change a thing.  My care providers just have to look at me and  they know what is wrong Johanna Greenburg and  Dr Salari  are the best i just love them both.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9989569e-01 1.0432797e-04]
#
# Text: He told me a few things I needed to do and he didnt write them down on the follow up sheet I took home. The nurse attempted to recall everything but I would have liked a more detailed list of things I should do and when I should do them. But otherwise everyone was great
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9989593e-01 1.0410150e-04]
#
# Text: The Dr. has always been a good experiance.I am confident in his help with my wellbeing.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999194e-01 8.063378e-05]
#
# Text: She was recomended to me  it was a relaxing experience. I was comfortable right away with the facility the nurse medical student and then the doctor. She asked the right amount of questions and showed concern for me my problems and my future visits and care.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999168e-01 8.320418e-05]
#
# Text: good
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999268e-01 7.315166e-05]
#
# Text: we drove 400 miles to spend 5 minutes with the doctor to be told we have to come back for surgery ...something that could have been handled over the phone
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9989271e-01 1.0728253e-04]
#
# Text: See earlier comment.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9986148e-01 1.3850121e-04]
#
# Text: None bad.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999037e-01 9.628871e-05]
#
# Text: Very informative and caring
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999224e-01 7.761053e-05]
#
# Text: Loved Dr. Soissons nurse Terrie
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991763e-01 8.2333216e-05]
#
# Text: Dr. Smith was amazing with me and my daughter.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991536e-01 8.4643711e-05]
#
# Text: Our son really likes Lori Blair as do we.  We appreciate the way she takes care of him.  She has a great deal of patience with him and provides helpinformation for him and to us as her parentsguardians.  She seems genuinely concerned in what he has to say and takes the time to listen to him.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9990785e-01 9.2138922e-05]
#
# Text: My family and I just moved to the Daybreak area and I will continue using this medical facility for all my needs.  My doctor was amazing.  She really took her time explaining my options and listening to my concerns.  She did not push me one way or the other.  She basically laid out several options for birth control and let me choose which way I wanted to go.  I felt in control of my body and I felt comfortable in my decision because she took her time to educate me on my options.  She also went above and beyond in noticing my energy level was low and suggesting I increase my Vitamin D intake.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9988878e-01 1.1126229e-04]
#
# Text: I thought I was to get a replacement or new contact lens for the right eye but after talking to Dr Knowltons office Im not sure.  Dr Charlton would check the power of the lens and send the lens prescription to be made for me.  After talking to Dr Knowltons Office it appears I have to pay for an appointment to check to be sure the lens power is correct andor check to see if the lens needs to be replaced because of scratching warping etc.  Im not sure what Dr Knowlton is to do.
# True Label: 0
# Predicted Label: 0
# Probabilities: [0.9984151  0.00158489]
#
# Text: With Drs Pittman and Junkins I wish there was a higher value than Very Good.   These doctors are very caring very attentive and seem genuinely concerned with your wellbeing.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999151e-01 8.486606e-05]
#
# Text: Excellent care by all who treated me that day.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991536e-01 8.4683685e-05]
#
# Text: I DONT CARE FOR THE FACT THAT YOU NEVER SEE THE SAME DOCTOR TWICE. EVERY TIME I COME DOWN HERE FOR THE LAST SEVERAL YEARS I HAVENT SEEN THE SAME DOCTOR EVER. WHEN I COME TO SEE DR. MAROUCE I ALWAYS SEE HIM. i THINK THIS IS A FLAW IN YOUR SYSTEM WITH THE HEALTH CARE CLINIC. THE NURSE PRACTITIONER SPENDS A LOT MORE TIME WITH US THAN THE DOCTOR. LIKE 10 TIMES MORE AND SHE TELLS THE DOCTOR HOW I AM THE DOCTOR DOESNT HAVE A CLUE.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.998159e-01 1.841440e-04]
#
# Text: Dr. Nance has always been excellent to work with and that is why I have the greatest respect for her because she is down to earth and easy to understand.  She is a great asset to your staff and clinic.  Thanks to Dr. Nance I was able to celebrate another birthday
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999211e-01 7.889970e-05]
#
# Text: what more is there to say.  All 5s
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9987185e-01 1.2815939e-04]
#
# Text: I was so impressed that he was willing to come out on Sunday to the clinic and help me after having an emergency eye problem instead of sending someone else.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.99896049e-01 1.03881044e-04]
#
# Text: Dr. Mamilis is outstanding in this area
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999299e-01 7.012382e-05]
#
# Text: Jackie is awesome
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992514e-01 7.4868214e-05]
#
# Text: Dr. Clark is amazing I will be going back to her in my future pregnancies.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991703e-01 8.2926541e-05]
#
# Text: She was OUTSTANDING
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999151e-01 8.488467e-05]
#
# Text: Dr Kunkel has done a wonderful treating me for the condition that I have.  He does an exceptional job in all areas of treatment discussion of condition evaluating treatment options and shows a genuine concern for my health.  He is truly a remarkable doctor that has had a dramatic effect on my life...for the better
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999205e-01 7.952955e-05]
#
# Text: Heather Clark RN is the Clinical Nurse Coordinator for Dr. Selzman. She is so skilled and kind. I am so grateful for her kindness and compassion.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992263e-01 7.7403434e-05]
#
# Text: Good.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.999069e-01 9.314558e-05]
#
# Text: Very knowledgeable
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992025e-01 7.9697165e-05]
#
# Text: Dr Ragle has always been very personable and made me feel very comfortable with answering any questions I may have or to explain any treatment or followup that may be needed.  I dont feel rushed and he is very patient.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991703e-01 8.2949482e-05]
#
# Text: Although the news I found was so bad he made it seem so light.  Explained after care very well and answered all questions that I had with ease.  Thank you
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991822e-01 8.1763785e-05]
#
# Text: I have recommended Dr Crandall and the Moran Center to a number of people here and abroad.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9987137e-01 1.2862131e-04]
#
# Text: all good
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9992216e-01 7.7815952e-05]
#
# Text: All really good.
# True Label: 0
# Predicted Label: 0
# Probabilities: [9.9991596e-01 8.4082596e-05]
