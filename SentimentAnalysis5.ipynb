# %%
# !pip install transformers datasets torch pandas scikit-learn openpyxl accelerate -U

import pandas as pd
import torch
import re
import numpy as np
from sklearn.model_selection import train_test_split
from datasets import Dataset, DatasetDict
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# Load the Excel file from the local directory
file_path = r"C:\Users\Michael\Downloads\BERTmodel\Patient_Comment Coding Training and Test Data.xlsx"
data = pd.read_excel(file_path)

# Use the correct column names based on the inspection
correct_comment_column = 'careprovidercomments'
sentiment_score_column = 'Combined_Sentiment'
bert_sentiment_column = 'BERT_Sentiment'

# Work with the first 1000 rows
data = data.iloc[:1000]

# Drop rows with NaN values in the sentiment score column
data = data.dropna(subset=[sentiment_score_column])

# Print unique values in the sentiment score column after dropping NaNs
print("Unique values in the sentiment score column after dropping NaNs:", data[sentiment_score_column].unique())

# Function to clean punctuation
def clean_text(text):
    if isinstance(text, str):
        # Remove all punctuation except periods
        text = re.sub(r'[^\w\s.]', '', text)
    else:
        text = ''
    return text

# Clean the comments
data['cleaned_comment'] = data[correct_comment_column].apply(clean_text)

# Ensure sentiment scores are between 1 and 5
def ensure_sentiment_scores(data, column):
    if not data[column].between(1, 5).all():
        raise ValueError("Sentiment scores must be between 1 and 5.")

ensure_sentiment_scores(data, sentiment_score_column)

# Convert sentiment scores to 0-based index
data[sentiment_score_column] = data[sentiment_score_column] - 1


# Split the data into training and testing sets (80/20 split)
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42, shuffle = True)

# Print the sizes of the training and testing sets
print(f"Training set size: {len(train_data)} comments")
print(f"Test set size: {len(test_data)} comments")

# Free up memory by deleting the original dataframe
del data

# Convert the data to Hugging Face datasets: hugging face, this is where pandas came in, we needed pandas, why did we convert to hugging
train_dataset = Dataset.from_pandas(train_data)
test_dataset = Dataset.from_pandas(test_data)
dataset_dict = DatasetDict({"train": train_dataset, "test": test_dataset})

# Free up memory by deleting the Pandas dataframes
del train_data, test_data

# Initialize tokenizer with smaller max_length
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

def tokenize_function(examples):
    return tokenizer(examples['cleaned_comment'], padding='max_length', truncation=True, max_length=64)

tokenized_datasets = dataset_dict.map(tokenize_function, batched=True)

def format_labels(examples):
    examples["labels"] = [int(label) for label in examples[sentiment_score_column]]
    return examples

tokenized_datasets = tokenized_datasets.map(format_labels, batched=True)

# Free up memory by deleting the original datasets
del dataset_dict

# Print tokenized dataset sizes for debugging
print(f"Tokenized training set size: {len(tokenized_datasets['train'])} comments")
print(f"Tokenized test set size: {len(tokenized_datasets['test'])} comments")

# Load the model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=5)

# Training arguments with reduced batch sizes
training_args = TrainingArguments(
    #output_dir=r"C:\Users\Michael\Downloads\BERT_MODEL_TRAINING_RESULTS-20240701T162037Z-002",  # Update with your local path
    output_dir=r"/content/BERT_MODEL_TRAINING_RESULTS",
    overwrite_output_dir=True,
    eval_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    num_train_epochs=3,
    weight_decay=0.01,
    fp16=True,
    logging_strategy="steps",
    logging_steps=50,
)

# Define evaluation metrics
def compute_metrics(p):
    preds = np.argmax(p.predictions, axis=1)
    precision, recall, f1, _ = precision_recall_fscore_support(p.label_ids, preds, average='weighted')
    acc = accuracy_score(p.label_ids, preds)
    return {"accuracy": acc, "f1": f1, "precision": precision, "recall": recall}

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
    compute_metrics=compute_metrics,
)

# Print expected number of steps per epoch
expected_steps_per_epoch = len(tokenized_datasets['train']) // training_args.per_device_train_batch_size
print(f"Expected number of steps per epoch: {expected_steps_per_epoch}")

# Train the model
trainer.train()

# Unified predict function
def predict(texts, model, tokenizer, batch_size=4):
    model.eval()
    if not isinstance(texts, list):
        texts = texts.tolist()

    predictions = []
    probabilities = []

    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        encoded_inputs = tokenizer(batch_texts, padding=True, truncation=True, max_length=128, return_tensors='pt')

        with torch.no_grad():
            outputs = model(**encoded_inputs)

        logits = outputs.logits
        batch_probabilities = torch.nn.functional.softmax(logits, dim=-1)
        batch_predictions = torch.argmax(batch_probabilities, dim=-1)

        predictions.extend(batch_predictions.cpu().numpy())
        probabilities.extend(batch_probabilities.cpu().numpy())

    return np.array(predictions), np.array(probabilities)

def evaluate_model(test_dataset, model, tokenizer):
    texts = test_dataset['cleaned_comment']
    true_labels = test_dataset[sentiment_score_column].tolist()

    predictions, probabilities = predict(texts, model, tokenizer)

    precision, recall, f1, _ = precision_recall_fscore_support(true_labels, predictions, average='weighted')
    accuracy = accuracy_score(true_labels, predictions)

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

    return predictions, probabilities

# Convert the test dataset to a pandas DataFrame
test_data = tokenized_datasets['test'].to_pandas()

# Evaluate the model
predictions, probabilities = evaluate_model(test_data, model, tokenizer)

# Inspect the predictions and their probabilities

for i in range(len(test_data)):
    print(f"Text: {test_data['cleaned_comment'].iloc[i]}")
    print(f"True Label: {test_data[sentiment_score_column].iloc[i] + 1}")
    print(f"Predicted Label: {predictions[i] + 1}")
    print(f"Probabilities: {probabilities[i]}")
    print()

# Re-load the full dataset including comments without sentiment scores
full_data = pd.read_excel(file_path)

# Clean the comments
full_data['cleaned_comment'] = full_data[correct_comment_column].apply(clean_text)

# Predict BERT sentiment scores for all comments
comments_to_predict = full_data['cleaned_comment'].tolist()
predicted_labels, predicted_probabilities = predict(comments_to_predict, model, tokenizer)

# Add predicted labels to the data in the BERT_Sentiment column
full_data[bert_sentiment_column] = predicted_labels + 1  # Convert back to 1-based index

# List of columns to keep
columns_to_keep =['ID', 'unidentifiableid', 'Combined_Sentiment', 'Combined_Wait', 'Combined_Mistake',
       'BERT_Sentiment', 'BERT_Wait', 'BERT_Mistake','careprovidercomments'
# Drop columns not in the list
full_data = full_data[columns_to_keep]

# Save the combined data with predictions back to the original Excel file
full_data.to_excel(file_path, index=False)  # Overwrite the original file
# Out:
# Requirement already satisfied: transformers in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (4.44.2)
# Requirement already satisfied: datasets in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (2.21.0)
# Requirement already satisfied: torch in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (2.4.0)
# Requirement already satisfied: pandas in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (1.5.1)
# Requirement already satisfied: openpyxl in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: accelerate in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (0.33.0)
# Requirement already satisfied: filelock in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.5.0)
# Requirement already satisfied: aiohttp in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.9.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: et-xmlfile in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: psutil in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: six>=1.5 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\michael\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch) (1.3.0)
# Unique values in the sentiment score column after dropping NaNs: [1. 2. 4. 5. 3.]
# Training set size: 799 comments
# Test set size: 200 comments
# C:\Users\Michael\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Map:   0%|          | 0/799 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/799 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Tokenized training set size: 799 comments
# Tokenized test set size: 200 comments
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Expected number of steps per epoch: 399
#     <div>
#
#       <progress value='1200' max='1200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1200/1200 34:15, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.646400</td>
#       <td>0.340710</td>
#       <td>0.895000</td>
#       <td>0.871667</td>
#       <td>0.857941</td>
#       <td>0.895000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.420500</td>
#       <td>0.337274</td>
#       <td>0.930000</td>
#       <td>0.911823</td>
#       <td>0.903301</td>
#       <td>0.930000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.488800</td>
#       <td>0.309208</td>
#       <td>0.935000</td>
#       <td>0.917482</td>
#       <td>0.901753</td>
#       <td>0.935000</td>
#     </tr>
#   </tbody>
# </table><p>
# C:\Users\Michael\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Michael\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Michael\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Michael\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9400
# Precision: 0.9053
# Recall: 0.9400
# F1 Score: 0.9220
# Text: Very polite softspoken confidence in himself.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.7363602e-05 1.2681616e-04 1.8493568e-04 3.5365441e-04 9.9924731e-01]
#
# Text: i guess im never sure that what i go in for is actually solved until i am able to see the results from the prescriptions. he was perfectly great through my appointment so i do hope that the results are as equally good. the appointment really was perfectly fine overall.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.6448609e-04 1.9550594e-04 3.4736266e-04 6.4867112e-04 9.9864393e-01]
#
# Text: Highly professional and friendly
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.5160824e-05 1.3600643e-04 1.9740716e-04 3.3334721e-04 9.9923813e-01]
#
# Text: The Dr. has always been a good experiance.I am confident in his help with my wellbeing.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.5596595e-05 1.2740494e-04 2.1040751e-04 4.0966520e-04 9.9915695e-01]
#
# Text: Dr. Muntz is an amazing doctor and in the four years that he has been our daughters doctor we have never felt like she was getting anything but the very best care.  Dr. Muntz is absolutely an amazing doctor and there are not enough words to express our deep appreciation for what he has done for Abbie.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0921229e-04 1.5048028e-04 2.4219294e-04 4.3499461e-04 9.9906319e-01]
#
# Text: very professional caring
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0070434e-04 1.4290196e-04 1.9863884e-04 3.2435913e-04 9.9923337e-01]
#
# Text: Everyone but especially Dr. Halwani treated my in an amazing manner on this visit.  I was moved to tears by the  time and attention he gave to me
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.1039696e-04 1.4738060e-04 2.3469626e-04 4.7282191e-04 9.9903476e-01]
#
# Text: Dr. Elrod did an amazing job with helping me through my situation. I believe she had genuine concern for me and made me feel like I would be okay hopeful0. I am okay I feel much better. She is an awesome DR.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.1166832e-05 1.1918598e-04 1.8637505e-04 3.3267430e-04 9.9927062e-01]
#
# Text: I totally trust my Doctor who has my best interests at heart understanding my individual limitations.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.7596723e-05 1.2341284e-04 1.9965625e-04 3.8736372e-04 9.9920195e-01]
#
# Text: Dr. Tristani is wonderful
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.07660766e-04 1.45192898e-04 2.05836914e-04 3.12694145e-04
#  9.99228597e-01]
#
# Text: Dr. Kolb was just terrific relaxed attentive caring thorough in history and physical extremely good at eliciting concerns and answering questions involved the patient and family in decision making about further evaluation and management. Its hard to imagine how his care could have been any better
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0393349e-04 1.3359675e-04 2.1394274e-04 3.5484135e-04 9.9919373e-01]
#
# Text: Great exprience. Even though my problem is minor compared to other patients I always felt like the most important person there. Dr. Soission is wonderful and he makes a scary experience more comfortable.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.05556785e-04 1.29513428e-04 2.09417834e-04 3.32534401e-04
#  9.99222994e-01]
#
# Text: I LOVE Dr. Kokeny MD she is a WONDERFUL CARING person. She has and is my favorite Dr. she listens and has such great kindness THANK YOU
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.9533565e-05 1.3242121e-04 1.8185705e-04 3.0423221e-04 9.9928194e-01]
#
# Text: Laura is the best  bar none
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.8315260e-04 2.0269511e-04 4.3458768e-04 4.8965402e-04 9.9868995e-01]
#
# Text: Dr. Moshifar is a highly skilled professional  He does a great job.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.1323491e-05 1.2438840e-04 1.8111858e-04 3.1710273e-04 9.9928612e-01]
#
# Text: Love her
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [4.0679882e-04 6.2664301e-04 9.1972185e-04 2.7743718e-03 9.9527246e-01]
#
# Text: Dr. Glenn is above all very professional but also very encouraging and friendly when I see her.  She answers my questions and does not try to hurry me out.  I have complete confidence in her and her treatment plan for me.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.7256649e-05 1.2859187e-04 2.0410369e-04 3.8974980e-04 9.9918026e-01]
#
# Text: Good experience
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.0750960e-05 1.2965327e-04 2.1606295e-04 4.5424362e-04 9.9910933e-01]
#
# Text: Dr. Harrie is excellent
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.9081379e-05 1.3735796e-04 1.9904737e-04 3.2030902e-04 9.9924421e-01]
#
# Text: good
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [0.00146977 0.00226827 0.00262662 0.01903437 0.974601  ]
#
# Text: We love Dr. Peterson. He is professional appropriately funny genuine and brilliant.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.2533555e-05 1.2557708e-04 1.7538761e-04 3.1116037e-04 9.9929535e-01]
#
# Text: Excellent in all matters.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.3420109e-05 1.3100814e-04 2.2115755e-04 4.4443816e-04 9.9910992e-01]
#
# Text: Excellent
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.2478988e-04 1.7337126e-04 3.1926497e-04 6.9782382e-04 9.9868470e-01]
#
# Text: I have been extremely pleased with the health care Dr. Dayton and his staff have provided.  This includes clinic visit prior to my operation my operation and recovery stay and my followup check ups after surgery.  I know I am getting the best care there at University of Utah Medical.  Thanks.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0149598e-04 1.3855204e-04 2.0393157e-04 4.6496573e-04 9.9909103e-01]
#
# Text: Dr. Backmann is a great physician. He took great care of me. He also replied to my MyChart message promptly.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.4389667e-05 1.2648645e-04 2.0147642e-04 3.7662042e-04 9.9920100e-01]
#
# Text: Dr. Craig is a wonderful doctor.   He has helped me so much with my health issues.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.1105525e-05 1.2438004e-04 1.9002044e-04 3.3467449e-04 9.9925977e-01]
#
# Text: After my apt i was getting dressed and my right leg lost feeling and my left leg went num on me making it very painful and hard to walk. Dr Kolb came right to my attention when I couldnt walk. My legs were extremely weak and when I asked him if it was normal for that to happen he said no and ran over asap grabbed a chair sat me down and ran to get help before going into his next appointment.
# True Label: 4.0
# Predicted Label: 1
# Probabilities: [0.98589605 0.00837062 0.00271023 0.00163334 0.00138984]
#
# Text: It was a promising visit
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [4.7828309e-04 5.3738110e-04 8.5805921e-04 2.4909037e-03 9.9563533e-01]
#
# Text: My urologist is the best.  Cant praise him enough.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.5731234e-04 1.8747285e-04 3.8033759e-04 6.8029127e-04 9.9859458e-01]
#
# Text: She was very thorough but to the point.   I was in and out and felt like I was taken care of.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.2609114e-04 1.5407134e-04 2.8146876e-04 5.8838056e-04 9.9884999e-01]
#
# Text: Dr. Koening is a very caring Physicial.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.4391973e-05 1.3149809e-04 1.9266763e-04 3.2737694e-04 9.9925405e-01]
#
# Text: Intelligent efficient without hurry useful discussion and information sense of humor
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.9320103e-05 1.3211240e-04 2.0813536e-04 4.0059612e-04 9.9915981e-01]
#
# Text: I always enjoy coming to visit Dr. Zinkaham. He is kind and caring He listens well to my concerns. He is an amazing caring Dr.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.3415678e-05 1.2649692e-04 1.7647193e-04 3.1420938e-04 9.9928939e-01]
#
# Text: Doctor Day spent an enormous amount of focus figuring out what was causing my problem. The result of her evaluation was that I was sent to the hospital for potential Pulmonary Embolisms in the lung. Dr. Day was spot on and saved my life. There was an excellent chance I would not have made it. DR. DAY IS THE BEST AND I OWE HER MY LIFE. WHAT A KNOWLEDGEABLE AND PERCEPTIVE AND TAKE CHARGE PERSON
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.2915548e-04 1.7099897e-04 2.5615282e-04 5.6464574e-04 9.9887902e-01]
#
# Text: Dr. Buys took extra time to actually diagram out a complicated process for me. I am a visualy learner so this really helped me to understand. She also demonstrated great compassion towards me when I explained some of my anxieties. She didnt treat me like just another patient.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.1605024e-04 1.4700629e-04 2.5435581e-04 4.6359908e-04 9.9901903e-01]
#
# Text: Have recommended Dr. Hoffman on several occasions.  He has been great to work with.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.95765697e-05 1.21937104e-04 1.84926554e-04 3.48374015e-04
#  9.99255121e-01]
#
# Text: Never saw my primary Doctor so the above questions are meaningless.
# True Label: 2.0
# Predicted Label: 1
# Probabilities: [0.6763162  0.06351299 0.19437192 0.04044126 0.02535772]
#
# Text: Good.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [0.0015072  0.00262125 0.00242346 0.01162062 0.98182744]
#
# Text: Dr. Saltzman as always is an excellent clinician and teacher.  I always refer anyone who asks me I am a physician about serious footankle problems or for a second opinion to him.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.1250937e-04 1.4420006e-04 2.2207155e-04 4.2210377e-04 9.9909914e-01]
#
# Text: I have never been to any medical facility where I was treated so well.  All of my concerns were met with professionalism and in terms I understood.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.2749250e-04 1.7651613e-04 2.8679031e-04 6.8621093e-04 9.9872297e-01]
#
# Text: Dr. Vanhorn is great. I really feel like me and my baby are in good hands.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.8909706e-05 1.1946562e-04 1.7937455e-04 3.4132783e-04 9.9927098e-01]
#
# Text: I was meeting the entire staff for the first time and was so pleased with the care and concern they showed to me . I was so relieved to FINALLY find medical personal that was listening and seemed to understand my condition.  This problem has been a serious issue for many months and has caused me and my family serious stress.  At last I was being given the  answers I  had been searching for.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0608566e-04 1.3603350e-04 2.0789767e-04 4.3889965e-04 9.9911112e-01]
#
# Text: Dr. Berks is the best.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.69107787e-05 1.21164354e-04 1.92439722e-04 3.39356571e-04
#  9.99250114e-01]
#
# Text: Dr. Jackson has been kind competent and compassionate. Everything a rheumatologist should be.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.3176830e-05 1.2492338e-04 1.8856194e-04 3.4061060e-04 9.9925274e-01]
#
# Text: The med student or resident Rebecca came in first and did a detailed history with me to understand the background of the problem as well as the acutecurrent symptoms.  She was professional and very thorough.  She had a genuine sense of concern.   I liked how she thought of all of my medical problems wholistically rather than just focusing on the few symptoms I was presenting that day.  I particularly liked how she considered the fact that I was pregnant.  She then consulted with Doc Ragle.  They came in together with a great list of solutions that allowed me to manage my asthma and sinus issues which were likely a contributor of my current symptoms cold respiratory infection.  Most of the medical advice I had received about my regular inhalers and  nasal spray was to avoid them as much as possible while pregnant.  Dr Ragel and his student came up with alternate meds to help manage the underlying problem.  Awesome.  A set of class B drugs is a far better solution than none at all.  Already after only being on the meds for 23 days I can already feel relief in both my asthma symptoms and my sinus congestion.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.3864004e-04 1.9174628e-04 2.9450640e-04 6.6829717e-04 9.9870682e-01]
#
# Text: Dr. VanCuran is absolutely amazing.  I am so glad to have him as my primary care physician.  I feel he is truly concerned with my health issues
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.3429007e-05 1.2836116e-04 1.8589632e-04 3.2432153e-04 9.9926800e-01]
#
# Text: Dr. Hood and staff were great
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0008469e-04 1.3250687e-04 1.9678689e-04 3.2388282e-04 9.9924672e-01]
#
# Text: Dr. Wilder was excellent
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0103461e-04 1.3064990e-04 2.0505246e-04 3.2778323e-04 9.9923551e-01]
#
# Text: Exceptional Doctor
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.3070987e-05 1.2784453e-04 1.9524700e-04 3.3661418e-04 9.9924719e-01]
#
# Text: Love Dr. Pham and the nurse assistant was very helpful and friendly also. My visit was excellent.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.8318451e-05 1.3138245e-04 1.8532931e-04 3.1911430e-04 9.9926585e-01]
#
# Text: I have not had better care anywhere.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [0.17253527 0.03550215 0.12435095 0.03270487 0.63490677]
#
# Text: I do not plan to go back.  Ive decided to go to another Dr. Next week at my own expence if necessary.  I have Retinites Pigmentosis and need a doctor I feel confident in.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [0.75627047 0.05881405 0.10482907 0.02482339 0.05526299]
#
# Text: I have aleady reffered a frind.
# True Label: 4.0
# Predicted Label: 5
# Probabilities: [0.09624806 0.06347775 0.22615142 0.08552592 0.5285969 ]
#
# Text: because the appointment was quite openthe physician visit included an undergraduate from another institutionI did not feel that I had an opportunity to discuss sensitive issues.  I would at least like to have been asked about the shadowingI know this is a teaching hospital and I expect some  of that but this was not even someone from the U
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [9.7343045e-01 1.4167259e-02 9.2320880e-03 2.2886025e-03 8.8163122e-04]
#
# Text: I was being seen for a cold that had settled in my lungs bad cough that was keeping me awake at night and a twisted ankle that had swollen up and was very sensative.  The Dr seemed very uncompassionate about my ankle when he asked me to get up on the exam table to listen to my lungs I had a hard time stepping up because of my sore ankle and his response was Well you walked in here just step up  I feel that if he had been just a little more compassionate it would have made my visit more favorable.  I was given some cough syrup and some exrays for my foot... after waiting for some time for the xray tech to review the shots I was told that it wasnt broken and it would get better.  Nothing like you should wrap it  or it will feel better if you place ice on it etc.  I just felt either he had other things on his mind perhaps it was a bad day or something but I didnt get the warm fuzzies that I usually have when visiting the stansbury clinic.  Usually Ive been treated so differently.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [9.8734260e-01 7.7166529e-03 2.6298340e-03 1.4489132e-03 8.6209370e-04]
#
# Text: Dr. Thulin was very helpful in addressiing the problem of delusions.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0203469e-04 1.3607045e-04 2.1139176e-04 3.4816895e-04 9.9920231e-01]
#
# Text: Although I have never heard from the physician about my lab results.
# True Label: 2.0
# Predicted Label: 3
# Probabilities: [0.29836488 0.09848872 0.44645536 0.08443214 0.07225888]
#
# Text: He did an amazing job of explaining all the issues and concerns I had.  He was very skilled in his observations and technique.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.8652665e-05 1.2706539e-04 2.1525027e-04 4.0622088e-04 9.9915278e-01]
#
# Text: he is the BEST
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.4097712e-05 1.2507434e-04 2.2488060e-04 4.0387776e-04 9.9915206e-01]
#
# Text: Dr. Cooper has always been responsive courteous personable.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.9327262e-05 1.3116089e-04 1.8451935e-04 3.0936001e-04 9.9927562e-01]
#
# Text: Too long to wait between visits.  Ive done what I was told and would like to see the provider for a follow up.  Next available is OCTOBER and it is July now.  I need the help NOW so waiting that long is not good.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [9.7839510e-01 1.2002418e-02 6.7653274e-03 1.9791285e-03 8.5794751e-04]
#
# Text: Nancy Veit was the nurse practitioner and she was superb  thorough detailed interested and explained everything very well. She also has been great at my follow up questions and returning calls as soon as possible.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.9170305e-05 1.2648526e-04 1.8298056e-04 3.2555789e-04 9.9926585e-01]
#
# Text: Dr. Williams is very knowledgeable and can see my situation from my view.  Hes the only doctor who could do this for me.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.8620560e-05 1.2072009e-04 1.8878910e-04 3.7640592e-04 9.9922550e-01]
#
# Text: I felt like Dr. Shelton just brushed aside my problem. I understand hes an awesome and smart doctor but I felt like he didnt really listen to me. Seemed in a hurry.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [0.98084337 0.01050092 0.00384251 0.00217473 0.00263845]
#
# Text: Wonderful doctor  makes going to the doctor something to look forward to.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.1004718e-04 1.3774802e-04 2.3964347e-04 3.8876076e-04 9.9912375e-01]
#
# Text: With each visit I am more impressed and inspired.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.1694609e-04 1.4330215e-04 2.5209982e-04 3.8637046e-04 9.9910128e-01]
#
# Text: Information about returning to work was very confusing.  I thought Id be going back Monday after surgery realized I would not be working for 2 weeks.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [9.8558652e-01 8.7084603e-03 3.2209170e-03 1.6174510e-03 8.6661946e-04]
#
# Text: We have many specialists for our daughters care. Dr. Meier is by far one of our favorites. He is the perfect combination of friendly caring bedside manner along with unparalleled expertise. He is thoughtful intentional and always listens to our ideas and concerns. He realizes that we are very well informed parents and adapts our conversations to an appropriate level. Ive already recommended him to others as we feel like we won the ENT lottery
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.3453295e-05 1.2282107e-04 1.8877364e-04 3.5603909e-04 9.9923897e-01]
#
# Text: Again my experience at the clinic has always been very good.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.7182834e-05 1.2797244e-04 1.9868584e-04 3.4938625e-04 9.9922681e-01]
#
# Text: The information that I attain each time I go is very good. Both my husband and I are very pleased with this facility and have had the opportunity toexperience other topo grande institutions which cannot hold a candle to you.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.6601696e-05 1.2712521e-04 1.9991174e-04 3.8770854e-04 9.9918860e-01]
#
# Text: great doctor just had to wait forever
# True Label: 3.0
# Predicted Label: 5
# Probabilities: [1.8053586e-04 1.9938269e-04 3.2354149e-04 4.1722375e-04 9.9887925e-01]
#
# Text: I was under some stress during one appointment and doctor was busy. I was trying to understand a situation I was in that did not make sense to me. Other than that my visits to clinic 2 have been great and overall the staff and doctor are very good at what they do.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [0.9670687  0.01304221 0.00707548 0.00259529 0.0102183 ]
#
# Text: This is a good group
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.7284433e-04 2.1279466e-04 4.4776435e-04 9.4540149e-04 9.9822122e-01]
#
# Text: He does work quickly and speaks fast so Im glad he has an asst. transcribing for him
# True Label: 3.0
# Predicted Label: 5
# Probabilities: [1.3632652e-04 1.9102890e-04 3.3518576e-04 7.0342189e-04 9.9863404e-01]
#
# Text: Followup care given via phone by nurse to my husband very confusing.  Not clear what the doctor wanted my husband to do.  Nurse gave conflicting information.  When calling on the phone to patients the message should be short precise and clear.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [9.8699284e-01 7.6606330e-03 3.3808129e-03 1.3679384e-03 5.9781101e-04]
#
# Text: Bettykathyjodie great
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0650258e-04 1.5887918e-04 2.4773646e-04 4.7308710e-04 9.9901378e-01]
#
# Text: I had to go back a second time because they did not find the problem. The second time i went back they accused me of being on drugs they hounded me with questions not believing about my allergies that have been proved by an allergist and they told me they could not help me at the end of my time being there with any of my problems and they told me to go find another doctor who is willing.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [9.8539364e-01 8.7756636e-03 3.4335002e-03 1.5974934e-03 7.9971965e-04]
#
# Text: Only the best Michelle you could open up your own clinic and you would be very successful.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.4952593e-05 1.2597759e-04 1.9546693e-04 3.6837821e-04 9.9921525e-01]
#
# Text: It always seems a little rushed at appt. there once you get in.  residents seem a little impersonal. Im a medical professional so Im always surprised that the residents seem so distracted and aloof.  They see a lot of patients I realize but they will when they start their practices so they ought to get off on the right foot.  How would they want to be treated if they were patients  I always try to think of that when Im at work at the hospital I work at.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [0.9807191  0.01240443 0.00356127 0.00217901 0.00113622]
#
# Text: This was a lab appt. so none of this applies sorry
# True Label: 3.0
# Predicted Label: 3
# Probabilities: [0.16559523 0.08947242 0.5517805  0.10198143 0.09117045]
#
# Text: The dr was wonderful I am glad that I chose to go to her because she took her time
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.1229953e-04 1.4523396e-04 2.4372779e-04 4.6014797e-04 9.9903858e-01]
#
# Text: Excellent
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.2478988e-04 1.7337126e-04 3.1926497e-04 6.9782382e-04 9.9868470e-01]
#
# Text: as mentioned before everything went well
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [2.0532687e-04 2.5659497e-04 4.6778173e-04 8.5934735e-04 9.9821091e-01]
#
# Text: Excellent experience.  Enjoyed a short visit with visiting China doctor Rebecca Tang.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.07894215e-04 1.43569137e-04 2.36492269e-04 3.91850685e-04
#  9.99120176e-01]
#
# Text: I was very impressed with Darin. He took the time to explain everything thoroughly and made sure we understood the evaluation process. Id highly recommend him to everyone I know.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.9119843e-05 1.2226570e-04 1.8793618e-04 3.8276872e-04 9.9921787e-01]
#
# Text: Theres a long wait list to be seen with Dr. Kiraly but she is definitely worth the wait
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [2.1454293e-04 2.8462493e-04 4.5350354e-04 7.6549087e-04 9.9828184e-01]
#
# Text: Dr Junkins and Dr Winter are both some of my very favorite doctors.  I have many doctors in my life.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.9234414e-05 1.2754230e-04 1.9261600e-04 3.0841713e-04 9.9927217e-01]
#
# Text: I had a student do my exam and the doctor was just in the room watching her.  I didnt mind having the student do the exam I just wish a I was talked to and not about so much while I was in the room with them.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [0.86898744 0.05263191 0.04414867 0.01560333 0.01862859]
#
# Text: I was impressed with the doctors concern for all my problems and questions.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.2895971e-05 1.2528339e-04 2.0346481e-04 4.1184537e-04 9.9916649e-01]
#
# Text: None bad.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [0.078908   0.03900668 0.34543505 0.08722813 0.44942215]
#
# Text: Lab Tech was AMAZING
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0171079e-04 1.3311223e-04 2.2492690e-04 3.8067054e-04 9.9915957e-01]
#
# Text: Dr. Summers gave evidence based treatment options for my medical concerns. It seems like he stays very current with research and practice.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.18836644e-04 1.53263201e-04 2.68679956e-04 5.20151283e-04
#  9.98939097e-01]
#
# Text: very good experience
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.6800744e-05 1.3845586e-04 1.9932662e-04 3.3078159e-04 9.9923468e-01]
#
# Text: At this clinic I will often see a different doctor than I scheduled with.
# True Label: 2.0
# Predicted Label: 1
# Probabilities: [0.46722728 0.1145959  0.28820547 0.06747184 0.06249958]
#
# Text: Dr. Tabin is very thorough.  She takes her time and listens to every complaint a very good doctor in my opinion.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.5884410e-05 1.2628999e-04 1.8964558e-04 3.2523856e-04 9.9926299e-01]
#
# Text: A very good experience.  Impressed by friendliness helpfulness and courtesy of staff.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.2463131e-05 1.2493307e-04 1.8873616e-04 3.3982442e-04 9.9925405e-01]
#
# Text: Dr. Hammoud made me feel like I was his top priority that day As it turns out my issue is relatively simple to remedy but the knowledge of that never changed his kindness towards me. I was so impressed
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0350711e-04 1.4400872e-04 2.3022604e-04 4.4523523e-04 9.9907696e-01]
#
# Text: My health care provider is EXCELLENT
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.9276163e-05 1.3022627e-04 2.1387365e-04 3.8250088e-04 9.9917406e-01]
#
# Text: I have been VERY impressed with Brett. My wife and mother now see him for all their care.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.7112894e-05 1.2174821e-04 1.8416649e-04 3.7523182e-04 9.9923170e-01]
#
# Text: If Dr. Sontheimer could be my primary care I would do that. Hes the best physician Ive ever visited.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0963348e-04 1.5589996e-04 2.4469011e-04 5.6940736e-04 9.9892044e-01]
#
# Text: Dr. Farouk is one of the better Clinical Physicians.  She was recommended to me by my husband when he worked with her.  Now thats saying something
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.3902341e-04 1.7407650e-04 3.1822198e-04 5.1173667e-04 9.9885690e-01]
#
# Text: very personable doctor which is a rare treat these days
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.9939563e-05 1.3834947e-04 2.1226810e-04 3.5952692e-04 9.9918991e-01]
#
# Text: Joanne was great very thorough and listened to all my concerns and was very detailed about all the things that could possibly be going on and explaining a course of treatment and when it should resolve.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.5521733e-05 1.2896092e-04 1.8789257e-04 3.6729104e-04 9.9922037e-01]
#
# Text: Your survey needs to have either a NA box or instructions to indicate not to check any box if a question is nonapplicable.
# True Label: 3.0
# Predicted Label: 3
# Probabilities: [0.32534674 0.12673143 0.39624178 0.10369818 0.0479819 ]
#
# Text: I DONT CARE FOR THE FACT THAT YOU NEVER SEE THE SAME DOCTOR TWICE. EVERY TIME I COME DOWN HERE FOR THE LAST SEVERAL YEARS I HAVENT SEEN THE SAME DOCTOR EVER. WHEN I COME TO SEE DR. MAROUCE I ALWAYS SEE HIM. i THINK THIS IS A FLAW IN YOUR SYSTEM WITH THE HEALTH CARE CLINIC. THE NURSE PRACTITIONER SPENDS A LOT MORE TIME WITH US THAN THE DOCTOR. LIKE 10 TIMES MORE AND SHE TELLS THE DOCTOR HOW I AM THE DOCTOR DOESNT HAVE A CLUE.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [0.980755   0.01211058 0.00401494 0.00208109 0.00103846]
#
# Text: none since it was only a walk in for flue shot
# True Label: 3.0
# Predicted Label: 3
# Probabilities: [0.15410185 0.0988812  0.5436     0.12158739 0.0818296 ]
#
# Text: Dr. Warner is fantastic She is lively intelligent funny and kind. Shes perhaps one of the best doctors in the Moran and the only one I would recommend. Great job
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.7628239e-05 1.2442668e-04 1.7956461e-04 3.0505960e-04 9.9929333e-01]
#
# Text: perhaps the best service I can recall ever receiving
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.6407181e-04 2.2741346e-04 3.3913244e-04 1.0209875e-03 9.9824846e-01]
#
# Text: good
# True Label: 4.0
# Predicted Label: 5
# Probabilities: [0.00146977 0.00226827 0.00262662 0.01903437 0.974601  ]
#
# Text: great doctor. will stay with him and recommend him to others.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.8856672e-05 1.1828437e-04 1.9322113e-04 3.4649149e-04 9.9925309e-01]
#
# Text: This was a oneyear postsurgical followup visit. There was no discussion of medications.
# True Label: 3.0
# Predicted Label: 3
# Probabilities: [0.14445636 0.10838945 0.5323669  0.13412444 0.08066294]
#
# Text: We do like her she does grate
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0988087e-04 1.2974224e-04 2.2826983e-04 4.1110616e-04 9.9912101e-01]
#
# Text: Dr. Pippitt is friendly funny kind smart and doesnt make me feel stupid for asking questions.  She is always thinking about all options and does a great job laying them out for me in a way that helps me understand what is going on and what decisions Ill need to make.  I enjoy my visits to the clinic because Dr. Pippitt is so awesome
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.5132906e-05 1.2521823e-04 1.8697753e-04 3.6747815e-04 9.9922514e-01]
#
# Text: Dr Lowrance was superior in all aspects
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.8649798e-05 1.3215440e-04 2.0742163e-04 3.8362233e-04 9.9917811e-01]
#
# Text: Hutch is awesome
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.3332370e-04 1.7204275e-04 3.4499649e-04 7.1152946e-04 9.9863809e-01]
#
# Text: Dr. Resident and techs were great I was not told about the followup for the surgery but that is not until June so I am sure I will be told
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [5.3309667e-04 5.7796476e-04 1.0355723e-03 1.3608356e-03 9.9649256e-01]
#
# Text: The primary care physician is excellent however the experience I had with the neurosurgeon was very poor. He overlooked a specific condition that I had and perscribed a medicine that was contradictory to my condition. I had a severe reaction which resulted in a life threatening condition that I will now for the rest of my life have to take a preventive medicine for so the condition will not reoccur. I have also sustained kidney damage from the drug reaction so I have recurring doctor visits and bills.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [9.8710155e-01 7.8202859e-03 2.8246550e-03 1.3481743e-03 9.0528239e-04]
#
# Text: Dr. Morrill shows sincere concern. Any additional questions I have he is great about answering them.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.9935995e-05 1.2442455e-04 1.9837302e-04 3.7217545e-04 9.9921513e-01]
#
# Text: Again Dr. Shamus Carr is AMAZING  I would gladly refer him to anybody that needed any type of Thoracic surgery.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.5926523e-05 1.3225923e-04 1.9464891e-04 3.8432961e-04 9.9919289e-01]
#
# Text: It was a very good experience
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0726828e-04 1.4349456e-04 2.2820980e-04 4.1402032e-04 9.9910694e-01]
#
# Text: I would totally recommend this place to friends family and neighbors.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.1062412e-04 1.4524067e-04 2.6553043e-04 5.0170691e-04 9.9897695e-01]
#
# Text: Dr. Wilson seems genuinely concerned about my heart health.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.2037131e-05 1.2531572e-04 1.9505028e-04 3.5663671e-04 9.9923098e-01]
#
# Text: my grandchildren really like Dr. Flynn
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.2075010e-05 1.2893874e-04 1.8342205e-04 3.5939322e-04 9.9923623e-01]
#
# Text: I trust Dr Keri Gibson with my life. I was going through a miscarraige. She called me over the weekend  kept checking on me. when I ended up in the ER she was up at the hospital doing surgeries  came down several times during her busy day to check on me. Even though a D  C was the last option Dr Gibson  myself wanted to do I ended up needing a D  C and she made time to do that for me. She is always so caring and personable. She makes you feel as though you are her most important patient. I recommend her to everyone I love Dr Gibson
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [3.3117927e-04 2.4790017e-04 3.1801034e-04 5.2087830e-04 9.9858201e-01]
#
# Text: I have recommended Dr. Sawitzke to others.  I have 100 confidence in his care and judgement.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.3692066e-05 1.2681868e-04 1.8975820e-04 3.9442108e-04 9.9920529e-01]
#
# Text: I wish more providers were like Dr. Allred  Someone who genuinely cares about her patients.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.2159132e-04 1.5448367e-04 2.8928780e-04 4.5080722e-04 9.9898380e-01]
#
# Text: what more is there to say.  All 5s
# True Label: 5.0
# Predicted Label: 3
# Probabilities: [0.250907   0.08621429 0.42764106 0.0922576  0.14297998]
#
# Text: Everything was excellent
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.3688548e-05 1.2429460e-04 1.9145155e-04 3.7984815e-04 9.9921072e-01]
#
# Text: I have always received wonderful care from Dr. Ward and his staff
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.1399976e-05 1.2528533e-04 1.7917564e-04 3.3925771e-04 9.9926490e-01]
#
# Text: very good
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.1656206e-05 1.2773999e-04 1.9933141e-04 3.4061231e-04 9.9924064e-01]
#
# Text: We have been patients of Dr CangaSiao in her prior practice. I am so glad we can continue with her. No one has ever controlled Barbaras blood sugar like she has. We are grateful for her knowledge and do recommend her whenever we can.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0258398e-04 1.4847018e-04 2.1979331e-04 5.1859004e-04 9.9901056e-01]
#
# Text: I dont like being asked to feel out a survey each time I come in.
# True Label: 2.0
# Predicted Label: 3
# Probabilities: [0.2922623  0.10307739 0.4567931  0.09621672 0.05165049]
#
# Text: doesnt listen at all walks in room for 30 seconds then leaves
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [0.57998765 0.06079843 0.2600025  0.04566359 0.05354786]
#
# Text: I hate it you wait forever and then when the Doctor final comes in for 10 min. He then goes on to tell you things that will change your life forever. He then hands you off to a very nice man but he does not have time for you. He gives you the 411 about the stuff you desire the doctor was there.  The whole time youre so scared you are hoping that you are not eating your underwear.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [0.974969   0.01409509 0.00447188 0.0024878  0.00397619]
#
# Text: I saw 2 doctors that day. The one that did the ultrasound and my primary doctor I regularly see. I thought the physician who did my ultrasound was fantastic. I felt like he was open to all my questions thoughtful patient and respectful. It felt like he was willing to talk over my ideas concerns and thoughts. When my primary doctor arrived I felt I had a different experience. I really appreciated him coming to see me not on a scheduled appt however I just felt like he wasnt really listening to concerns and thoughts I had about alternative treatments and trying other things. I feel like the doctors already have their minds made up sometimes and not willing to consider other types of treatment.
# True Label: 1.0
# Predicted Label: 5
# Probabilities: [3.3922339e-04 2.8394946e-04 3.8569845e-04 5.6120375e-04 9.9842995e-01]
#
# Text: We couldnt ask for any better
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [0.13776782 0.05897238 0.24474321 0.08919574 0.4693208 ]
#
# Text: The MD didnt tell me anything about my medications.  Someone called me the next day and told me they called in an rx for me.
# True Label: 2.0
# Predicted Label: 1
# Probabilities: [0.77254677 0.05803618 0.09655396 0.04483782 0.02802527]
#
# Text: Dr Penrod always does a good job and is friendly
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.7152966e-05 1.3457093e-04 1.7904169e-04 3.3215049e-04 9.9925703e-01]
#
# ...
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.1956288e-05 1.2526513e-04 1.9078424e-04 4.1575739e-04 9.9917620e-01]
#
# Text: I have always had a very good service at the Redwood Clinic The testing was done very well I have no complaints.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.03906634e-04 1.29175227e-04 1.99326620e-04 3.59533267e-04
#  9.99208033e-01]
#
# Text: the doc was a fun guy...very patient with questions and explanations and we even traded a joke or two.  He laughed...how novel and pleasant.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.4723453e-04 1.7521824e-04 3.2370829e-04 5.6551566e-04 9.9878830e-01]
#
# Text: mammography technician so helpful told her I was traveling for a few months and could radiologist read the report so Victoria PA could report to me if all was normal. What an incredible staff  Thanks again
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.1417643e-04 1.5536630e-04 2.3615213e-04 4.9818499e-04 9.9899608e-01]
#
# Text: I was rushed and didnt get to talk to him about all of my concerns. He said I needed to see an orthopedic which I want to do but he didnt give me a recommendation as to who to see. I also wanted to talk to him about seeing a phyciatrist or therapist about my depression but didnt get the chance.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [0.9791525  0.01278565 0.00416885 0.00252328 0.0013698 ]
#
# Text: Everyone was very helpful.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.98443905e-05 1.19180884e-04 1.80153002e-04 3.34424491e-04
#  9.99276459e-01]
#
# Text: Dr. Andtbacka and staff were great.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.5387266e-05 1.2566970e-04 1.8628337e-04 3.2663770e-04 9.9926597e-01]
#
# Text: She was really really great answered questions took my concerns seriously and gave me great care
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.5695323e-05 1.2492205e-04 1.8324112e-04 3.2254728e-04 9.9927360e-01]
#
# Text: He spend more time than he probably had.  Hopefully he didnt miss an appointment that was elsewhere on campus.  It was just so good to finally talk to a professional about Parkinsons.  I have to say Im still afraid of the damaging effects of the disease when taking medicines.  Certainly had a hope for awhile that exercise and will power could keep the symptoms at bay. Everything has moved quickly in last 6 months.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [2.3287589e-04 2.7856103e-04 3.4447282e-04 8.9669391e-04 9.9824739e-01]
#
# Text: Excellent Doctor
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.4695788e-05 1.2542377e-04 1.9301273e-04 3.3138270e-04 9.9925548e-01]
#
# Text: Grateful to have an expert in my condition who is taking care of me...
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.3207491e-05 1.3163456e-04 2.0583443e-04 4.6630131e-04 9.9910307e-01]
#
# Text: The dr. under fellowship was great also and listened to what I said and then acted upon it.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.1486495e-04 1.4680233e-04 2.6204783e-04 5.0091540e-04 9.9897540e-01]
#
# Text: I have received wonderful care from Dr. Sharp
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.9443158e-05 1.2670727e-04 1.7763772e-04 3.4430256e-04 9.9926192e-01]
#
# Text: I am a customer service fanatic.  Dr. Raman is amazing.  He is incredibly thorough and very conscientious.  I have rarely had a doctor take the time and be as thorough and in depth as he is.  If all doctors were like Dr. Raman we would have a very different health care system.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0115614e-04 1.3448959e-04 2.1351193e-04 3.6147534e-04 9.9918932e-01]
#
# Text: Dr. Moshifar wrote down exactly what I needed to purchase and how to use the medications prescribed. He also outlined and drew a picture of the problem areas of my eye. He was very clear and precise in his instruction.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.1939975e-04 1.5778920e-04 2.5441236e-04 5.1690161e-04 9.9895144e-01]
#
# Text: Awesome Dr Katz... I recommend him whenever the opportunity arrises
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.6496922e-05 1.3393235e-04 2.1138425e-04 3.7713803e-04 9.9918109e-01]
#
# Text: Wonderfull
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.9507030e-05 1.3166720e-04 2.2842514e-04 4.7637546e-04 9.9906403e-01]
#
# Text: Dr. Agerwal is the best We love him
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.3966963e-05 1.2933083e-04 1.8497555e-04 3.1957496e-04 9.9927217e-01]
#
# Text: Very pleased
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.6798030e-05 1.3516699e-04 2.0911425e-04 3.4842294e-04 9.9921048e-01]
#
# Text: she outlined my options from cortisone shot to physical therepy and let me choose which I felt like I wanted to do.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [0.0046664  0.00459367 0.00859233 0.00949044 0.9726572 ]
#
# Text: Very courteous and helpful
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.1811722e-05 1.3501267e-04 1.9647994e-04 3.4594670e-04 9.9923074e-01]
#
# Text: I would highly recommend Dr. Robert Hood to anyone in need of back surgery.  He spent a lot of time with my husband and me discussing what needed to be done to correct the problem with my vertebrae which were out of alignment.  The surgery and recovery went very well and I no longer suffer from painful sciatica.  Im very grateful
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0875184e-04 1.4245826e-04 2.1861197e-04 4.5961712e-04 9.9907058e-01]
#
# Text: I like Dr Greis. If not I would find someone else.  The resident that was working with him that day was not my favorite. I was getting a synvisc shot in my knee. He jammed the needle in  forced the plumber down so quickly... it seemed more like he was administering an epi pen. The pain and pressure were so much that I tensed up and moaned with pain. The resident told me I needed to relax. He finished up by putting a single bandaid on the site and said I could get dressed and leave when ready. Usually they apply some gauze and wrap my knee. I ended up doing that myself at home since I was bleeding through the provided bandaid.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [0.98378193 0.00969999 0.00351548 0.00190727 0.00109537]
#
# Text: Dr. Sharp is very congenial and professional
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.7081160e-05 1.4060874e-04 1.9071974e-04 3.3013211e-04 9.9924147e-01]
#
# Text: Years ago this care provider was recommended to me.   I would do the same for other people with a need.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.4332547e-04 1.8641360e-04 3.3186688e-04 6.9754967e-04 9.9864084e-01]
#
# Text: Dr. Moss is an affable experienced physician who engenders confidence. He is thorough in his explanations.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.1309856e-05 1.2485827e-04 1.9986878e-04 3.9188354e-04 9.9919206e-01]
#
# Text: Great
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.6366327e-04 2.0275330e-04 4.1112793e-04 8.7335904e-04 9.9834907e-01]
#
# Text: DR. MAMALIS IS VERY PROFESSIONAL AND COURTEOUS TO HIS PATIENTS AND AS i HAVE MENTIONED TO HIM BEFORE HE TEACHES THE MEDICAL STUDENTS UNDER HIM AS COLLEAGUES AND NOT AS UNDERLINGS.  iT IS AN INSPIRING WAY TO TEACH
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.9197568e-05 1.3180036e-04 2.1528680e-04 3.6486881e-04 9.9918884e-01]
#
# Text: I ALWAYS RECOMMEND THE hUMTSMAN
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.14415074e-04 1.47960920e-04 2.64434057e-04 4.80561081e-04
#  9.98992622e-01]
#
# Text: I had waited 2 years for an ankle replacement.  The experience was nothing but great all through the process.  From Lindsay setting up surgery and appointment to Drs visits to post surgery in the hospital it was all very positive.  I have a great deal of confidence my results will be great
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.2368991e-04 1.4908231e-04 2.3572834e-04 4.3103856e-04 9.9906045e-01]
#
# Text: very knowledgeable
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.3457864e-05 1.3304873e-04 2.0079952e-04 3.3150412e-04 9.9924123e-01]
#
# Text: He was great to resolve my cholesterol worries and change my medication to something better.  He also found an infection on my foot that had minor surgery previously and made sure I had an antibiotic before the long weekend.  He communicated several times in person and on My Chart.  Dr. Van Curan and Tara are wonderful.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.04176666e-04 1.34843169e-04 2.21365714e-04 4.26386221e-04
#  9.99113262e-01]
#
# Text: I remain as I have been for years a big fan of Dr Tim Odell. I have lived all over the world and rate Tim as one of the two best internists I have ever had.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.5648225e-05 1.2272965e-04 1.9499737e-04 3.6659907e-04 9.9922001e-01]
#
# Text: all good
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.7979639e-05 1.3210958e-04 2.0714574e-04 3.5193725e-04 9.9921083e-01]
#
# Text: My care providers are the best that i have ever had. Would never change a thing.  My care providers just have to look at me and  they know what is wrong Johanna Greenburg and  Dr Salari  are the best i just love them both.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.8444762e-05 1.2647478e-04 1.9777581e-04 4.1802190e-04 9.9915934e-01]
#
# Text: Dr. Tricot is absolutely the most caring physician that I have ever known. The genuine love of his profession of healing is very evident by his hard work and many years of education with his focus on multiple myeloma. Every patient knows he is the most important person at the time of his visit and that he has the full attention of the Doctor. Yet Dr. Tricot never fails to inquire about the patients family which brings the element of real concern for the whole wellbeing of those for which he is attending.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.8908520e-05 1.2879376e-04 1.8406854e-04 3.9975636e-04 9.9919850e-01]
#
# Text: All good
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.7979639e-05 1.3210958e-04 2.0714574e-04 3.5193725e-04 9.9921083e-01]
#
# Text: Love Julia...very informative and made me feel that she cared.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.3138013e-05 1.2331053e-04 1.9462327e-04 3.5334789e-04 9.9923563e-01]
#
# Text: I consider Dr. Bowen to be the very best.  It isnt necessary to my satisfection but I like him very much too.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.9299214e-05 1.2675357e-04 2.0113969e-04 3.8508489e-04 9.9918777e-01]
#
# Text: Dr. Smith had her nurse call me to check on my daughter Maggie.  She had a reaction to her Kindergarten immunizations and got a really high fever.  I had talked to a nurse the day after a couple of times and she was very helpful.  Then a couple of days later Dr. Smith had her nurse call to make sure that everything was O.K.  I really appreciated that and her concern.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.7909062e-04 2.1742439e-04 3.3192488e-04 6.4665638e-04 9.9862492e-01]
#
# Text: Ally is one of the best providers at Westridge. She has been amazing to me and my family and we are brokenhearted to see her leave. The clinic will not be the same without her.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.2844041e-04 1.5861636e-04 2.7388262e-04 4.9963477e-04 9.9893945e-01]
#
# Text: The staff is friendly which is helpful due to the sensitive nature of the appointment.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.3283752e-04 1.6223524e-04 3.0278100e-04 5.3243479e-04 9.9886972e-01]
#
# Text: Dr. Bowen always takes whatever time is needed to listen to my concerns. He makes sure I completely understand what treatments are needed. He is very professional friendly caring and thorough.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.2553826e-05 1.2250192e-04 1.8319192e-04 3.5342653e-04 9.9924833e-01]
#
# Text: I felt very comfortable and Dr. Aoki was so kind and understanding.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.3948387e-05 1.2932955e-04 1.8736147e-04 3.4039890e-04 9.9924892e-01]
#
# Text: good
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [0.00146977 0.00226827 0.00262662 0.01903437 0.974601  ]
#
# Text: Very Good
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.1656206e-05 1.2773999e-04 1.9933141e-04 3.4061231e-04 9.9924064e-01]
#
# Text: I felt very comfortable and the service was good I liked how they listen and asked questions.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0665315e-04 1.3316955e-04 2.2302617e-04 4.3718325e-04 9.9909997e-01]
#
# Text: I have absolute and unlimited trust in Dr. Boyer.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [8.9703273e-05 1.3605157e-04 2.0986566e-04 4.7305459e-04 9.9909139e-01]
#
# Text: Outstanding
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.1677786e-05 1.2981224e-04 2.2724968e-04 4.4991213e-04 9.9910140e-01]
#
# Text: Dr. Wilson has an excellent bedside manner.  I feel very comfortable with him and he makes me feel like he is giving me his complete attention.  Although I know hes very busy he never seems rushed.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0695210e-04 1.3134372e-04 2.1952388e-04 3.6210701e-04 9.9918002e-01]
#
# Text: very good
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.1656206e-05 1.2773999e-04 1.9933141e-04 3.4061231e-04 9.9924064e-01]
#
# Text: What can I say about perfect
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [0.00177899 0.00187675 0.00417591 0.00868476 0.9834837 ]
#
# Text: Although the news I found was so bad he made it seem so light.  Explained after care very well and answered all questions that I had with ease.  Thank you
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.2074959e-04 1.4108658e-04 2.5842612e-04 4.4087312e-04 9.9903893e-01]
#
# Text: This was my first visit and all the physician said to me was to say we would run some tests and then go from there.  The Nurse Practitioner was nice and explained things to me.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [3.5223112e-04 3.4798891e-04 5.0516357e-04 1.2964194e-03 9.9749821e-01]
#
# Text: Dr Andtbacka and his staff are great
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.7955737e-05 1.3347593e-04 1.9237604e-04 3.2706140e-04 9.9924916e-01]
#
# Text: Dr. Downey was amazing He gave us all the information we needed with the diagnosis kept us informed about the surgery and followed up after surgery with all the information we needed to feel secure about the procedure and care afterward. I would recommend him to anyone
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.1027130e-04 1.5059799e-04 2.3998202e-04 5.1994447e-04 9.9897921e-01]
#
# Text: I still dont really understand what is causing my issue. When I asked about pain medication I was told that its just a pain that I would have to deal with and he prescribed me some medication for arthritis or something that I dont even suffer from so I dont understand why the medication would be helpful. He suggested physical therapy for a long period of time even though it would be painful. He seemed rushed and I did not get to see all the photos from my MRI. Also the results of the MRI have not been posted to My Chart so I dont know what the radiologist that was going to read the images said.
# True Label: 1.0
# Predicted Label: 1
# Probabilities: [9.8122132e-01 1.1898769e-02 3.9911820e-03 2.1561643e-03 7.3275750e-04]
#
# Text: Dr. Caine is superb in all ways  He goes the extra mile and is very caring
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.7877666e-05 1.3129282e-04 1.9211220e-04 3.2483260e-04 9.9925381e-01]
#
# Text: Outstanding  thank you.
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [9.2265262e-05 1.3256531e-04 2.1294918e-04 3.7328879e-04 9.9918896e-01]
#
# Text: I have gone to Michelle for years she always make me feel that she is not rushed and listes to me.  She explains what is going on
# True Label: 5.0
# Predicted Label: 5
# Probabilities: [1.0116609e-04 1.2987283e-04 2.0970720e-04 3.9551847e-04 9.9916375e-01]
